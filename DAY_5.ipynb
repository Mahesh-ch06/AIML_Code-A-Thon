# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh-ch06/AIML_Code-A-Thon/blob/main/DAY_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GITHUB Repositories

# %% [markdown]
# [DAY 5](https://github.com/Mahesh-ch06/AIML_Code-A-Thon/blob/main/DAY_4.ipynb)

# %% [markdown]
# # CODE-A-THON DAY 5 CHALLENGE

# %% [markdown]
# **TODAYS TASK**
#
# **RANDOM FOREST CLASSIFICATION :**
#
# Write a Python program in Google Colab to perform an end-to-end analysis using SURVEY LUNG CANCER  DATASET provided, using RANDOM FOREST CLASSIFICATION as the model  :
#
# RANDOM FOREST
# 1. Import necessary libraries
# 2.Load the dataset
# 3.Remove any leading or trailing whitespace from column names
# 4.Display the first few rows and column names to confirm cleanup
# 5.Check for any missing values
# 6. Data Preprocessing
# # Encoding categorical variables if any exist
# 7.Separate features and target variable
# 8.Split data into training and testing sets
# USE test_size=0.5 and random_state=42
# 9.Initialize the Random Forest Classifier
# USE n_estimators=100, AND random_state=42
# 10.Train the model
# 11.Make predictions
# 12.Evaluate the model
#
#  **ACCURACY**
#
#   **CLASSIFICATION REPORT**
#
#   **CONFUSION MATRIX**
#
# 13. Feature importance Graph
#
# NOTE: IN TRAIN_TEST SPLITTING,DEFINE
#
# TEST_SIZE=0.5
#
# RANDOM_STATE=42
#
# IN Initializing the Random Forest Classifier
#
# n_estimators=100,
# random_state=42

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
# Load dataset
data = pd.read_csv('/content/survey lung cancer.csv')

# %%
data
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %%
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
# ...

# %% [markdown]
# # Remove any leading or trailing whitespace from column names

# %%
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %% [markdown]
# # Display the first few rows and column names to confirm cleanup

# %%
print("First few rows of the dataset:")
data.head()
# Out:
# First few rows of the dataset:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1        2        1         2                  2         2
# 1                2        2        2         1                  1         1
# 2                1        2        1         2                  1         2
# 3                1        1        1         1                  2         1
# 4                1        1        1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# ...

# %%
print("\nColumn names:", data.columns)
# Out:
# Column names: Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE', 'ALLERGY', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %% [markdown]
# # Check for any missing values

# %%
print(data.isnull().sum())
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# # Data Preprocessing - Encoding categorical variables if any exist

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
data['GENDER'] = label_encoder.fit_transform(data['GENDER'])
data['LUNG_CANCER'] = label_encoder.fit_transform(data['LUNG_CANCER'])

# %% [markdown]
# # Separate features and target variable

# %%
X = data.drop('LUNG_CANCER', axis=1)
y = data['LUNG_CANCER']

# %% [markdown]
# # Split data into training and testing sets (test_size=0.5, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %% [markdown]
# # Initialize the Random Forest Classifier (n_estimators=100, random_state=42)

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %% [markdown]
# # Train the model

# %%
rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # Make predictions

# %%
y_pred = rf_classifier.predict(X_test)

# %% [markdown]
# # Evaluate the model

# %%
print("\nModel Accuracy:", accuracy_score(y_test, y_pred))
print("\nModel Accuracy:", accuracy_score(y_test, y_pred)*100) # Converting into percentage
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Model Accuracy: 89.03225806451613
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.43      0.41        14
#            1       0.94      0.94      0.94       141
#
#     accuracy                           0.89       155
#    macro avg       0.67      0.68      0.68       155
# weighted avg       0.89      0.89      0.89       155
#
#
# Confusion Matrix:
# [[  6   8]
#  [  9 132]]

# %% [markdown]
# # Feature importance Graph

# %%
feature_importances = rf_classifier.feature_importances_
features = X.columns

# %% [markdown]
# # Plotting feature importances

# %%
# Plotting feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importances, y=features)
plt.title("Feature Importance in Random Forest Model")
plt.xlabel("Importance")
plt.ylabel("Features")
plt.show()
