# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh-ch06/AIML_Code-A-Thon/blob/main/DAY_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GITHUB Repositories

# %% [markdown]
# [DAY 4](https://github.com/Mahesh-ch06/AIML_Code-A-Thon/blob/main/DAY_4.ipynb)

# %% [markdown]
# # CODE-A-THON DAY 4 CHALLENGE

# %% [markdown]
# **TODAYS TASK**
#
# **DECISION TREE CLASSIFICATION :**
#
# Write a Python program in Google Colab to perform an end-to-end analysis using CAR EVALUATION DATASET provided, using DECISION TREE CLASSIFICATION as the model  :
#
# 1. import libraries
# 2. Load the CSV file
# 3. Encode categorical data
# 4. One-hot encode categorical features in X
# 5. Define features (X) and target (y)
# 6. Split the dataset into training and testing sets
# 7. Initialize and train the Decision Tree Classifier
# 8. Predict on the test data
# 9. Calculate accuracy
# 10. classification report
# 11. Plot confusion matrix as a heatmap
#
# NOTE: IN TRAIN_TEST SPLITTING,DEFINE
#
# TEST_SIZE=0.7
#
# RANDOM_STATE=42

# %% [markdown]
# # import libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

# %% [markdown]
# # Load the Dataset

# %%
# Load dataset
data = pd.read_csv('/content/car_evaluation_codethon.csv')

# %%
data
# Out:
#      buying price maintenance cost number of doors number of persons lug_boot  \
# 0           vhigh            vhigh               2                 2    small
# 1           vhigh            vhigh               2                 2    small
# 2           vhigh            vhigh               2                 2    small
# 3           vhigh            vhigh               2                 2      med
# 4           vhigh            vhigh               2                 2      med
# ...           ...              ...             ...               ...      ...
# 1723          low              low           5more              more      med
# 1724          low              low           5more              more      med
# 1725          low              low           5more              more      big
# 1726          low              low           5more              more      big
# 1727          low              low           5more              more      big
#
#      safety decision
# ...

# %%
data.head()
# Out:
#   buying price maintenance cost number of doors number of persons lug_boot  \
# 0        vhigh            vhigh               2                 2    small
# 1        vhigh            vhigh               2                 2    small
# 2        vhigh            vhigh               2                 2    small
# 3        vhigh            vhigh               2                 2      med
# 4        vhigh            vhigh               2                 2      med
#
#   safety decision
# 0    low    unacc
# 1    med    unacc
# 2   high    unacc
# 3    low    unacc
# 4    med    unacc
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_3.groupby('lug_boot').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# # Encode categorical data

# %%
label_encoders = {}
for column in data.columns:
    le = LabelEncoder()
    data[column] = le.fit_transform(data[column])
    label_encoders[column]=le

# %% [markdown]
# # One-hot encode categorical features in X

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

onehot_encoder = OneHotEncoder(sparse_output=False)
X = onehot_encoder.fit_transform(X)

# %% [markdown]
# # Define features (X) and target (y)

# %%
X = data.drop('decision', axis=1)
y = data['decision']

# %% [markdown]
# # Split the dataset into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# %% [markdown]
# # Initialize and train the Decision Tree Classifier

# %%
classifier = DecisionTreeClassifier(random_state=42)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %% [markdown]
# # Predict on the test data

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Calculate accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
percentage_accuracy = accuracy * 100
print("Accuracy:", percentage_accuracy,"%")
# Out:
# Accuracy: 94.9586776859504 %

# %%
accuracy
# Out:
# 0.9495867768595041

# %% [markdown]
# #  Generate classification report

# %%
report = classification_report(y_test, y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       260
#            1       0.82      0.69      0.75        45
#            2       0.97      0.98      0.98       862
#            3       0.79      0.95      0.86        43
#
#     accuracy                           0.95      1210
#    macro avg       0.88      0.88      0.87      1210
# weighted avg       0.95      0.95      0.95      1210

# %% [markdown]
# # Plot confusion matrix as a heatmap

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix - Decision Tree Classifier')
plt.show()

# %%
# Displaying results
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(f"Accuracy: {accuracy*100:.2f}") # Converting into percentage
print("\nClassification Report:\n", report)
print("\nConfusion Matrix:\n", conf_matrix)
# Out:
# Accuracy: 0.95
# Accuracy: 94.96
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       260
#            1       0.82      0.69      0.75        45
#            2       0.97      0.98      0.98       862
#            3       0.79      0.95      0.86        43
#
#     accuracy                           0.95      1210
#    macro avg       0.88      0.88      0.87      1210
# weighted avg       0.95      0.95      0.95      1210
#
#
# Confusion Matrix:
#  [[232   5  19   4]
#  [  1  31   6   7]
#  [ 17   0 845   0]
#  [  0   2   0  41]]

# %%
submission = pd.DataFrame({
    'Accuracy': [accuracy]
})
submission = submission[['Accuracy']]
submission.to_csv('DAY-4.csv', index=False)
print("Submission file 'DAY-4.csv' created successfully.")
# Out:
# Submission file 'DAY-4.csv' created successfully.

# %%
df = pd.read_csv('/content/DAY-4.csv')
df
# Out:
#    Accuracy
# 0  0.949587

# %%
accuracy_value = accuracy*100
plt.figure(figsize=(4, 6))
plt.bar(['Accuracy'], [accuracy_value], color='skyblue')
plt.ylim(0, 100)
plt.ylabel("Accuracy (%)")
plt.title("Model Accuracy")
plt.text(0, accuracy_value + 2, f"{accuracy_value:.2f}%", ha='center', va='bottom', fontsize=12)
# Out:
# Text(0, 96.9586776859504, '94.96%')
